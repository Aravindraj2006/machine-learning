# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
train = pd.read_csv('titanic_train.csv')

# %% [markdown]
# ## Passenger list

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### to see how many passenger are there in the list

# %%
train.shape
# Out:
# (891, 12)

# %% [markdown]
# ### To see the null value

# %%
train.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train.apply(len,axis=1)
# Out:
# 0      12
# 1      12
# 2      12
# 3      12
# 4      12
#        ..
# 886    12
# 887    12
# 888    12
# 889    12
# 890    12
# Length: 891, dtype: int64

# %%
train.apply(len,axis = 0)
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            891
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          891
# Embarked       891
# dtype: int64

# %% [markdown]
# ## To see the null value on visual

# %%
sns.heatmap(train.isnull(),yticklabels = False)
# Out:
# <Axes: >

# %% [markdown]
# ## Show the relationship between the column

# %%
ar = train.select_dtypes(include = ['number'])
sns.heatmap(ar.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(train[['Age', 'Fare', 'Pclass', 'Survived']], hue='Survived')
plt.show()
# Out:
# C:\Users\freaky manoj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## countplot to show people who survived
# ### 0 means they not survived and 1 means they survived

# %%
sns.set_style('whitegrid')
sns.countplot(x = 'Survived',data = train)
plt.title('Survived or not')
# Out:
# C:\Users\freaky manoj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\freaky manoj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# #### many of them were not survived

# %% [markdown]
# ## Survival based on gender

# %%
sns.countplot(x = 'Survived',hue = 'Sex',data=train)
plt.title("Survival based on gender")
# Out:
# C:\Users\freaky manoj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\freaky manoj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# #### it show that men were not survived more

# %% [markdown]
# ## Survival based on passenger class

# %%
sns.countplot(x = 'Survived',hue = 'Pclass',data = train)
plt.title("Survival based on passenger class ")
# Out:
# C:\Users\freaky manoj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\freaky manoj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ### it show that 3rd class passenger were not survived more

# %% [markdown]
# ## To show the age of passenger on visual

# %%
sns.countplot(x = 'Age',data = train)
# Out:
# C:\Users\freaky manoj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\freaky manoj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ### its not looking good so we use distplot

# %%
sns.distplot(train['Age'].dropna(),kde = False,bins = 40)
# .dropna to remove the null value
# Out:
# C:\Users\freaky manoj\AppData\Local\Temp\ipykernel_16960\2171433782.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train['Age'].dropna(),kde = False,bins = 40)
# <Axes: xlabel='Age'>

# %% [markdown]
# ## to show the passenger travel with siblings

# %%
sns.countplot(x='SibSp',data = train)
# Out:
# C:\Users\freaky manoj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\freaky manoj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ## to show the relation between age of passenger and passengerclass on boxplot

# %%
sns.boxplot(x = 'Pclass',y='Age',data = train)
# Out:
# C:\Users\freaky manoj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\freaky manoj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ### it show that on 1st class the mean age of passenger were near 37 and for 2nd class  is near 29 and for 3rd class is near 24

# %% [markdown]
# ## there is more null value on age

# %% [markdown]
# ### show I made a function to see the age of every passenger if any passenge age is null see their passenger class if 1st class make them age as 37 and 2nd class means 29 and 3rd class means 24

# %%
def impute_age(row):
    Age = row[0]  
    Pclass = row[1]
    if pd.isnull(Age):
        if Pclass == 1:
            return 37
         
        elif Pclass == 2:
            return 29
        
        else:
            return 24
        
    else:
        return Age
    
    
''' Age       22.0
    Pclass     3
    Name: 0, dtype: object
    to acess the fist value as age we given as Age  = row[0] and Pclass = row[1]
'''
# Out:
# ' Age       22.0\n    Pclass     3\n    Name: 0, dtype: object\n    to acess the fist value as age we given as Age  = row[0] and Pclass = row[1]\n'

# %%
train['Age']  =train[['Age','Pclass']].apply(impute_age,axis = 1)
# axis is to give one by one row value if axis = 0 or axis is not given it taken by column wise
# Out:
# C:\Users\freaky manoj\AppData\Local\Temp\ipykernel_16960\3796734079.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Age = row[0]
# C:\Users\freaky manoj\AppData\Local\Temp\ipykernel_16960\3796734079.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Pclass = row[1]

# %% [markdown]
# ### now we see that on heatmap there is no null value on age

# %%
sns.heatmap(train.isnull(),yticklabels = False)
# Out:
# <Axes: >

# %% [markdown]
# ## Cleaning

# %% [markdown]
# ### we see that there is more null value on cabin show we removed that

# %%
train.drop('Cabin',axis = 1,inplace  = True)
# .drop is to remove the row or column
# axis = 1 to column 
# inplace drop it in the main dataset

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
sns.heatmap(train.isnull())
# Out:
# <Axes: >

# %%
train.shape
# Out:
# (891, 11)

# %%
type(train)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ##  the ML model cant understand the text so we changing the the text into number

# %%
pd.get_dummies(train['Embarked'],drop_first = True).head()
# the ML model cant understand the text so we changing the the text into number
# Out:
#        Q      S
# 0  False   True
# 1  False  False
# 2  False   True
# 3  False   True
# 4  False   True

# %%
Embarked  = pd.get_dummies(train['Embarked'],drop_first = True).head().astype(int)
Embarked.head()
# .astype to compulsory convert into integer
# Out:
#    Q  S
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  1
# 4  0  1

# %%
sex = pd.get_dummies(train['Sex'],drop_first = True).astype(int)
print(sex.dtypes)
# Out:
# male    int32
# dtype: object

# %%
train.drop(['Sex','Embarked','Name','Ticket'],axis = 1,inplace = True)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1         0       3  22.0      1      0   7.2500
# 1            2         1       1  38.0      1      0  71.2833
# 2            3         1       3  26.0      0      0   7.9250
# 3            4         1       1  35.0      1      0  53.1000
# 4            5         0       3  35.0      0      0   8.0500

# %%
train = pd.concat([train,sex,Embarked],axis = 1)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  male    Q    S
# 0            1         0       3  22.0      1      0   7.2500     1  0.0  1.0
# 1            2         1       1  38.0      1      0  71.2833     0  0.0  0.0
# 2            3         1       3  26.0      0      0   7.9250     0  0.0  1.0
# 3            4         1       1  35.0      1      0  53.1000     0  0.0  1.0
# 4            5         0       3  35.0      0      0   8.0500     1  0.0  1.0

# %%
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Age            float64
# SibSp            int64
# Parch            int64
# Fare           float64
# male             int32
# Q              float64
# S              float64
# dtype: object

# %%
train.groupby('male')['Survived'].mean()
# Out:
# male
# 0    0.742038
# 1    0.188908
# Name: Survived, dtype: float64

# %%
train[train['Age'] < 10]['Survived'].mean()
# Out:
# 0.6129032258064516

# %%
train.groupby('Age')['Survived'].mean()
# Out:
# Age
# 0.42     1.0
# 0.67     1.0
# 0.75     1.0
# 0.83     1.0
# 0.92     1.0
#         ...
# 70.00    0.0
# 70.50    0.0
# 71.00    0.0
# 74.00    0.0
# 80.00    1.0
# Name: Survived, Length: 88, dtype: float64
